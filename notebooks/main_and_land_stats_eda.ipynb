# %%
import pandas as pd

# %%
unit_stats = pd.read_csv(r"..\data\clean\main_and_land_stats.csv", dtype=str, keep_default_na=False)
unit_stats.shape
# Out:
# (2595, 20)

# %%
unit_stats.columns.tolist()
# Out:
# ['unit',
#  'caste',
#  'land_unit',
#  'num_men',
#  'man_entity',
#  'armour',
#  'charge_bonus',
#  'melee_attack',
#  'melee_defence',
#  'morale',
#  'primary_melee_weapon',
#  'mass',
#  'hit_points',
#  'size',
#  'bonus_v_large',
#  'damage',
#  'ap_damage',
#  'melee_weapon_type',
#  'melee_attack_interval',
#  'armour_value']

# %%
unit_stats.dtypes
# Out:
# unit                     str
# caste                    str
# land_unit                str
# num_men                  str
# man_entity               str
# armour                   str
# charge_bonus             str
# melee_attack             str
# melee_defence            str
# morale                   str
# primary_melee_weapon     str
# mass                     str
# hit_points               str
# size                     str
# bonus_v_large            str
# damage                   str
# ap_damage                str
# melee_weapon_type        str
# melee_attack_interval    str
# armour_value             str
# dtype: object

# %%
# Need int instead of str
unit_stats.columns.tolist()
# Out:
# ['unit',
#  'caste',
#  'land_unit',
#  'num_men',
#  'man_entity',
#  'armour',
#  'charge_bonus',
#  'melee_attack',
#  'melee_defence',
#  'morale',
#  'primary_melee_weapon',
#  'mass',
#  'hit_points',
#  'size',
#  'bonus_v_large',
#  'damage',
#  'ap_damage',
#  'melee_weapon_type',
#  'melee_attack_interval',
#  'armour_value']

# %%
unit_stats = unit_stats.astype({
    "num_men": "int64",
    "armour_value": "int64",
    "charge_bonus": "int64",
    "melee_attack": "int64",
    "melee_defence": "int64",
    "morale": "int64",
    "hit_points": "int64",
    "bonus_v_large": "int64",
    "damage": "int64",
    "ap_damage": "int64",
    "melee_attack_interval": "float64",
})

unit_stats.dtypes
# Out:
# unit                         str
# caste                        str
# land_unit                    str
# num_men                    int64
# man_entity                   str
# armour                       str
# charge_bonus               int64
# melee_attack               int64
# melee_defence              int64
# morale                     int64
# primary_melee_weapon         str
# mass                         str
# hit_points                 int64
# size                         str
# bonus_v_large              int64
# damage                     int64
# ap_damage                  int64
# melee_weapon_type            str
# melee_attack_interval    float64
# armour_value               int64
# dtype: object

# %%
unit_stats.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2595 entries, 0 to 2594
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   unit                   2595 non-null   str
#  1   caste                  2595 non-null   str
#  2   land_unit              2595 non-null   str
#  3   num_men                2595 non-null   int64
#  4   man_entity             2595 non-null   str
#  5   armour                 2595 non-null   str
#  6   charge_bonus           2595 non-null   int64
#  7   melee_attack           2595 non-null   int64
#  8   melee_defence          2595 non-null   int64
#  9   morale                 2595 non-null   int64
#  10  primary_melee_weapon   2595 non-null   str
#  11  mass                   2595 non-null   str
#  12  hit_points             2595 non-null   int64
#  13  size                   2595 non-null   str
#  14  bonus_v_large          2595 non-null   int64
# ...

# %%
unit_stats["size"].unique() # categorisch ordinaal?
# Out:
# <StringArray>
# ['small', 'medium', 'large', 'very_large', 'very_small']
# Length: 5, dtype: str
